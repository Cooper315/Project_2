# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session, sessionmaker, scoped_session
from sqlalchemy import create_engine
from sqlalchemy import func
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd

# %%
con = create_engine("sqlite:///../NFA_data.db")
chunks = pd.read_csv('NSF_expenditures.csv', chunksize=50000)
for chunk in chunks:
    chunk.to_sql(name='NSF', if_exists='append', con=con)

# %%
df = pd.read_sql_table('NSF', con=engine)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Id, NSFName, RDINST, UnitId, Year, AcademicDiscipline, FedFinancedSERD, StateFinancedSERD, BusinessFinancedSERD, InstitutionFinancedSERD, OtherFinancedSERD, TotalSERDExpenditures, ARRAFinancedRD, StateFinancedRD, BusinessFinancedRD, NonProfitFinancedRD, InstitutionFinancedRD, OtherFinancedRD, ForeignFinancedRD, ContractFinancedRD, GrantFinancedRD, MedSchoolRDExpenditures, ClinicalTrialRDExpenditures, FedFinancedClinicalTrialRDExpenditures, EquipmentRDExpenditures, FedFinancedEquipmentRDExpenditures, TotalRDExpenditures]
# Index: []
#
# [0 rows x 27 columns]

# %%
df = pd.read_csv('NSF_expenditures.csv')

# %%
cols = df.columns.tolist()
df = df[cols[:len(cols)-1]]

# %%
index = Column(Integer, primary_key=True)
# Out:
# index                                       int64
# Id                                         object
# NSFName                                    object
# RDINST                                      int64
# UnitId                                    float64
# Year                                        int64
# AcademicDiscipline                         object
# FedFinancedSERD                             int64
# StateFinancedSERD                           int64
# BusinessFinancedSERD                        int64
# InstitutionFinancedSERD                     int64
# OtherFinancedSERD                           int64
# TotalSERDExpenditures                       int64
# ARRAFinancedRD                              int64
# StateFinancedRD                             int64
# BusinessFinancedRD                          int64
# NonProfitFinancedRD                         int64
# InstitutionFinancedRD                       int64
# OtherFinancedRD                             int64
# ...

# %%
df.to_csv('NSF_expenditures.csv')

# %%
df['TotalRDExpenditures'] = df['TotalRDExpenditures'].astype(str)

# %%
df.reset_index(inplace=True)
df
# Out:
#          index                                    Id  \
# 0            0  CFEC5241-51A7-48E7-B579-136B588CEA82
# 1            1  DA50B95F-6B7B-4355-A61C-39B5A8141050
# 2            2  A4265CFD-E92A-4ABB-BD61-86FC3D95EA75
# 3            3  1C40FFAD-F3E6-4D71-8DDA-0235D3692857
# 4            4  EAA2EAAE-A38C-47C5-8C4C-D4C02B3F3B96
# 5            5  D532C7A1-D095-4CD7-9819-6F21AE6D2F33
# 6            6  5969711B-F2B5-40D3-BF6B-B16A2E1EBFA3
# 7            7  11B66B4E-DA44-48C0-8B03-693373063F13
# 8            8  D283B3AB-6B3A-4478-B4EF-60D32AF41D2E
# 9            9  172CFC5F-FDA1-4992-93DE-3097B0C8B56C
# 10          10  9A25943B-9D08-4493-8D7B-DE9C4A098F69
# 11          11  55B37A3C-2674-40E7-999E-2AE49EFC0C40
# 12          12  99D7603E-3C5F-471B-8EF4-F94165000EF4
# 13          13  A5C53055-7111-44B5-A451-F51FDCC27B02
# 14          14  0DBF3E74-661D-4E23-A5A2-C738858FB498
# 15          15  087627D9-D823-4E98-BDB7-5D028C3B1A71
# 16          16  FF719C1B-BE09-4F5C-B018-A335A2B97DD6
# ...
